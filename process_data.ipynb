# %% [markdown]
# ## Process 800m splits from my race splits database

# %%
import pandas as pd
from time_parser import TimeParser as tp

# Read in data
data_200_splits = pd.read_csv('data/db_800m_splits.csv')

# Split into two datasets: 4 splits and 2 splits
data_400_splits = data_200_splits.copy()

splits_200m = data_200_splits.dropna()
splits_200m

splits_400m = data_400_splits[data_400_splits.isna().any(axis=1)]
splits_400m = splits_400m.drop(columns = ['lap_3', 'lap_4'])

# Parse time columns: convert string into seconds
splits_200m['lap_1_sec'] = [tp.parse_time(time) for time in splits_200m['lap_1']]
splits_200m['lap_2_sec'] = [tp.parse_time(time) for time in splits_200m['lap_2']]
splits_200m['lap_3_sec'] = [tp.parse_time(time) for time in splits_200m['lap_3']]
splits_200m['lap_4_sec'] = [tp.parse_time(time) for time in splits_200m['lap_4']]

splits_200m['first_400'] = splits_200m[['lap_1_sec', 'lap_2_sec']].sum(axis = 1)
splits_200m['second_400'] = splits_200m[['lap_3_sec', 'lap_4_sec']].sum(axis = 1)
splits_200m['total_time_sec'] = splits_200m[['first_400', 'second_400']].sum(axis = 1)

splits_200m.drop(columns = ['lap_1', 'lap_2', 'lap_3', 'lap_4',
                            'lap_1_sec', 'lap_2_sec', 'lap_3_sec', 'lap_4_sec'])
# Out:
# C:\Users\mitch\AppData\Local\Temp\ipykernel_1264\4147852610.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   splits_200m['lap_1_sec'] = [tp.parse_time(time) for time in splits_200m['lap_1']]
# C:\Users\mitch\AppData\Local\Temp\ipykernel_1264\4147852610.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   splits_200m['lap_2_sec'] = [tp.parse_time(time) for time in splits_200m['lap_2']]
# C:\Users\mitch\AppData\Local\Temp\ipykernel_1264\4147852610.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   splits_200m['lap_3_sec'] = [tp.parse_time(time) for time in splits_200m['lap_3']]
# C:\Users\mitch\AppData\Local\Temp\ipykernel_1264\4147852610.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   splits_200m['lap_4_sec'] = [tp.parse_time(time) for time in splits_200m['lap_4']]
# C:\Users\mitch\AppData\Local\Temp\ipykernel_1264\4147852610.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   splits_200m['first_400'] = splits_200m[['lap_1_sec', 'lap_2_sec']].sum(axis = 1)
# C:\Users\mitch\AppData\Local\Temp\ipykernel_1264\4147852610.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   splits_200m['second_400'] = splits_200m[['lap_3_sec', 'lap_4_sec']].sum(axis = 1)
#               athlete    lap_1    lap_2    lap_3    lap_4 total_time  \
# 3         lk boulware  0:37.07  0:42.16  0:44.97  0:42.67    2:45.87
# 4       laney mcgahey  0:41.30  0:46.76  0:48.47  0:47.00    3:02.53
# 12         sadie lyon  0:36.72  0:43.94  0:43.78  0:44.00    2:48.44
# 15   baden sanderford  0:29.06  0:31.07  0:30.56  0:32.10    2:02.79
# 17     colton thigpen  0:30.18  0:34.13  0:34.62  0:36.07    2:14.00
# 18      ethan michael  0:33.65  0:37.25  0:35.35  0:33.15    2:18.40
# 27   mary mac collins  0:34.75  0:33.94  0:35.31  0:39.52    2:23.52
# 28       kennae hales  0:37.91  0:39.28  0:42.00  0:40.71    2:39.90
# 29    sophie boxmeyer  0:41.47  0:44.33  0:44.36  0:43.55    2:53.71
# 30     preston barnes  0:28.50  0:31.88  0:33.34  0:35.00    2:09.09
# 31   baden sanderford  0:28.16  0:31.47  0:32.25  0:32.81    2:05.03
# 44  margaret rockhold  0:39.66  0:47.15  0:49.66  0:53.06    3:09.53
# 45         sadie lyon  0:36.75  0:41.44  0:43.78  0:42.27    2:44.24
# 46       linley byars  0:39.00  0:44.69  0:47.06  0:45.00    2:55.75
# 47      laney mcgahey  0:40.91  0:44.81  0:48.53  0:48.72    3:03.29
# 48      mia livaudais  0:43.66  0:48.22  0:48.34  0:50.37    3:10.59
